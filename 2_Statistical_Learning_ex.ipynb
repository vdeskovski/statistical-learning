# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # College data

# %%
college_df = pd.read_csv("data/College.csv")

# %%
college_df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
len(college_df)
# Out:
# 777

# %%
college_df.rename(columns={college_df.columns[0]: "College"},inplace=True)

# %%
college_df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college_df.set_index('College', inplace=True)

# %%
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %%
# C
college_df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# D
feature_names = ['Top10perc', 'Apps', 'Enroll']
pd.plotting.scatter_matrix(college_df[feature_names], alpha=1, figsize=(10, 8))
plt.show()

# %%
# E
college_df.boxplot('Outstate', by='Private')
plt.xlabel('Private')
plt.ylabel('Outstate')
plt.show()

# %%
# F

# %%
college_df['Top10perc'].hist()
# Out:
# <Axes: >

# %%
print("Mean =",college_df.Top10perc.mean())
print("Median =",college_df.Top10perc.median())
print("Min =",college_df.Top10perc.min())
print("Max =",college_df.Top10perc.max())
# Out:
# Mean = 27.55855855855856
# Median = 23.0
# Min = 1
# Max = 96

# %%
top10perc_breakpoint = college_df.Top10perc.median()

# %%
top10perc_max = college_df.Top10perc.max()

# %%
# from 0 to median (exclusive) will be categorized as 'No', from median to the max value (inclusive) as 'Yes'

# %%
college_df['Elite'] = pd.cut(college_df['Top10perc'], [0, top10perc_breakpoint, top10perc_max], labels=['No', 'Yes'])

# %%
college_df[['Top10perc', 'Elite']]
# Out:
#                                 Top10perc Elite
# College
# Abilene Christian University           23    No
# Adelphi University                     16    No
# Adrian College                         22    No
# Agnes Scott College                    60   Yes
# Alaska Pacific University              16    No
# ...                                   ...   ...
# Worcester State College                 4    No
# Xavier University                      24   Yes
# Xavier University of Louisiana         34   Yes
# Yale University                        95   Yes
# York College of Pennsylvania           28   Yes
#
# [777 rows x 2 columns]

# %%
college_df.Elite.value_counts()
# Out:
# Elite
# No     392
# Yes    385
# Name: count, dtype: int64

# %%
college_df.Elite.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Elite'>

# %%
college_df.boxplot('Outstate', by='Elite')
plt.xlabel('Elite')
plt.ylabel('Outstate')
plt.show()

# %% [markdown]
# ##### Higher Outstate tuition in the 'Elite' colleges as expected. A few outliers can be noticed in the NON 'Elite' colleges

# %%
# G

# %%
college_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 13))

college_df.Top10perc.plot.hist(ax = axes[0,0], bins=25)
axes[0, 0].set_title("Top10Perc ; Histogram ; Bins=25")

college_df.Top10perc.plot.hist(ax = axes[0,1], bins=50)
axes[0, 1].set_title("Top10Perc ; Histogram ; Bins=50")

college_df.Enroll.plot.hist(ax = axes[1,0], bins=25)
axes[1, 0].set_title("New students ; Histogram ; Bins=25")

college_df.Enroll.plot.hist(ax = axes[1,1], bins=50)
axes[1, 1].set_title("New students ; Histogram ; Bins=50")

college_df.Outstate.plot.hist(ax = axes[2,0], bins=25)
axes[2, 0].set_title("Outstate-Tuition ; Histogram ; Bins=25")

college_df.Outstate.plot.hist(ax = axes[2,1], bins=50)
axes[2, 1].set_title("Outstate-Tuition ; Histogram ; Bins=50")

plt.show()

# %%
# H

# %% [markdown]
# ### Which college enrolled the most new students?

# %%
row = college_df[college_df.Enroll == college_df.Enroll.max()]

# %%
row
# Out:
#                                    Private   Apps  Accept  Enroll  Top10perc  \
# College
# Texas A&M Univ. at College Station      No  14474   10519    6392         49
#
#                                     Top25perc  F.Undergrad  P.Undergrad  \
# College
# Texas A&M Univ. at College Station         85        31643         2798
#
#                                     Outstate  Room.Board  Books  Personal  \
# College
# Texas A&M Univ. at College Station      5130        3412    600      2144
#
#                                     PhD  Terminal  S.F.Ratio  perc.alumni  \
# College
# Texas A&M Univ. at College Station   89        91       23.1           29
#
#                                     Expend  Grad.Rate Elite
# College
# Texas A&M Univ. at College Station    8471         69   Yes

# %% [markdown]
# ### Which college has the highest Outstate tuition?

# %%
row = college_df[college_df.Outstate == college_df.Outstate.max()]

# %%
row
# Out:
#                    Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Bennington College     Yes   519     327     114         25         53
#
#                     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Bennington College          457            2     21700        4100    600
#
#                     Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Bennington College       500   35        59       10.1           33   16364
#
#                     Grad.Rate Elite
# College
# Bennington College         55   Yes

# %% [markdown]
# ### Percent of applicants accepted per college

# %%
college_df['Acception Rate'] = college_df.Accept / college_df.Apps

# %%
college_df['Acception Rate'] = college_df['Acception Rate'].round(3)

# %%
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# ### Enrollment rate per college

# %%
college_df['Enrollment Rate'] = college_df.Enroll / college_df.Accept
college_df['Enrollment Rate'] = college_df['Enrollment Rate'].round(3)
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
min_enrollment_rate = college_df[1:2]

# %%
pd.set_option('display.max_columns', None)

# %%
min_enrollment_rate
# Out:
#                    Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Adelphi University     Yes  2186    1924     512         16         29
#
#                     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Adelphi University         2683         1227     12280        6450    750
#
#                     Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Adelphi University      1500   29        30       12.2           16   10527
#
#                     Grad.Rate Elite  Acception Rate  Enrollment Rate
# College
# Adelphi University         56    No            0.88            0.266

# %% [markdown]
# ### Graduation rate by private colleges

# %%
college_df['Grad.Rate'].hist()
# Out:
# <Axes: >

# %%
college_df.boxplot('Grad.Rate', by='Private')
plt.xlabel('Private')
plt.ylabel('Grad.Rate')
plt.show()

# %% [markdown]
# ### Graduation rate by private and elite colleges

# %%
college_df.boxplot('Grad.Rate', by=['Private','Elite'])
plt.xlabel('Private & Elite')
plt.ylabel('Grad.Rate')
plt.title('Boxplot of Grad.Rate by Private and Elite')
plt.show()

# %% [markdown]
# # Auto data

# %%
auto_df = pd.read_csv("data/Auto.csv")

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# A
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
len(auto_df)
# Out:
# 397

# %%
len(auto_df.name.unique())
# Out:
# 304

# %%
# B, C
auto_df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# D

# %%
auto_df.drop(index=range(10,86)).describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  321.000000  321.000000    321.000000   321.000000    321.000000
# mean    24.444860    5.370717    187.174455  2933.183801     15.709034
# std      7.899928    1.653486     99.864568   809.638650      2.706441
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    145.000000  2795.000000     15.500000
# 75%     30.700000    6.000000    250.000000  3504.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  321.000000  321.000000
# mean    77.143302    1.598131
# std      3.128202    0.816163
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
# E

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto_df.drop(columns=['name'],inplace=True)

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
auto_df.drop(auto_df[auto_df.horsepower == '?'].index, inplace=True)

# %%
auto_df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %%
plt.figure(figsize=(8,5))
sns.heatmap(auto_df.corr(), annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
correlation_matrix = auto_df.corr()
#(correlation_matrix.abs() > 0.5).all()
#(correlation_matrix.abs() > 0.5).any()
high_correlation_columns = correlation_matrix.columns[(correlation_matrix.abs() > 0.5).any()]

# %%
high_correlation_columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin'],
#       dtype='object')

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# F

# %%
plt.figure(figsize=(8,5))
sns.heatmap(auto_df.corr(), annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
pd.plotting.scatter_matrix(auto_df, alpha=1, figsize=(20, 17))
plt.show()

# %% [markdown]
# ###### Based on the correlation and scatter matrix:
# ###### - cyclinders, displacement, horsepower and weight are attributes that will yield negative correlation, trying to predict 'mpg'
# ###### - on the other hand, acceleration, year and origin would yield a more positive correlation

# %%
auto_df.boxplot('mpg', by='year')
plt.xlabel('Year')
plt.ylabel('MPG')
plt.show()

# %%
auto_df.boxplot('mpg', by='origin')
plt.xlabel('Origin')
plt.ylabel('MPG')
plt.show()

# %%
auto_df.boxplot('mpg', by='cylinders')
plt.xlabel('Cylinders')
plt.ylabel('MPG')
plt.show()

# %%
auto_df.boxplot('mpg', by=['cylinders','origin'])
plt.xlabel('Cylinders & Origin')
plt.ylabel('MPG')
plt.show()

# %%
auto_df[(auto_df.cylinders == 5) & (auto_df.origin == 3)]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin]
# Index: []

# %% [markdown]
# # Boston data

# %%
# A
boston_df = pd.read_csv('data/Boston.csv')

# %%
boston_df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %%
# B
print(boston_df.columns)
boston_df.describe()
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'lstat', 'medv'],
#       dtype='object')
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# ...

# %%
# 1 row is a neighbourhood
# CRIM: Per capita crime rate by town.
# ZN: Proportion of residential land zoned for lots over 25,000 sq. ft.
# INDUS: Proportion of non-retail business acres per town.
# CHAS: Charles River dummy variable (1 if tract bounds river; 0 otherwise).
# NOX: Nitric oxides concentration (parts per 10 million).
# RM: Average number of rooms per dwelling.
# AGE: Proportion of owner-occupied units built before 1940.
# DIS: Weighted distances to five Boston employment centers.
# RAD: Index of accessibility to radial highways.
# TAX: Full-value property tax rate per $10,000.
# PTRATIO: Pupil-teacher ratio by town.
# LSTAT: Percentage of lower status of the population.
# MEDV: Median value of owner-occupied homes in $1000s (the target variable).

# %%
# C

# %%
boston_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
pd.plotting.scatter_matrix(boston_df, alpha=1, figsize=(20, 17))
plt.show()

# %%
plt.figure(figsize=(20,17))
sns.heatmap(boston_df.corr(), annot=True, fmt=".2f", annot_kws={'size': 18})
# Out:
# <Axes: >

# %% [markdown]
# ###### From this matrix we see that the target variable 'medv' is not correlated that much with 'chas'

# %%
# D

# %% [markdown]
# ###### I would say that all features are associated with crime rate (crim), except Charles river dummy var (chas)

# %%
# E

# %%
boston_df.crim.hist(bins=50)
# Out:
# <Axes: >

# %%
boston_df[boston_df.crim < boston_df.crim.max()].crim.hist(bins=50)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5, 10))
boston_df.boxplot('crim')
plt.xlabel('Crime Rate per Capita (CRIM)')
plt.title('Distribution of Crime Rates in Boston Suburbs')
plt.show()

# %% [markdown]
# ###### Numerous upper outliers

# %%
boston_df[boston_df.crim > boston_df.crim.max()-50]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
#
#      ptratio  lstat  medv
# 380     20.2  17.21  10.4
# 404     20.2  27.38   8.5
# 405     20.2  22.98   5.0
# 410     20.2  10.11  15.0
# 414     20.2  36.98   7.0
# 418     20.2  20.62   8.8

# %%
# F

# %%
boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
len(boston_df[boston_df.chas == 1]) # 35 is the answer
# Out:
# 35

# %%
# G

# %%
print("Median = ", boston_df.ptratio.median())
# Out:
# Median =  19.05

# %%
# H

# %%
boston_df_min_medv = boston_df[boston_df.medv == boston_df.medv.min()]

# %%
boston_df_min_medv
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
boston_df_min_medv.describe()
# Out:
#            crim   zn  indus  chas    nox        rm    age       dis   rad  \
# count   2.00000  2.0    2.0   2.0  2.000  2.000000    2.0  2.000000   2.0
# mean   53.13630  0.0   18.1   0.0  0.693  5.568000  100.0  1.457500  24.0
# std    20.90844  0.0    0.0   0.0  0.000  0.162635    0.0  0.045396   0.0
# min    38.35180  0.0   18.1   0.0  0.693  5.453000  100.0  1.425400  24.0
# 25%    45.74405  0.0   18.1   0.0  0.693  5.510500  100.0  1.441450  24.0
# 50%    53.13630  0.0   18.1   0.0  0.693  5.568000  100.0  1.457500  24.0
# 75%    60.52855  0.0   18.1   0.0  0.693  5.625500  100.0  1.473550  24.0
# max    67.92080  0.0   18.1   0.0  0.693  5.683000  100.0  1.489600  24.0
#
#          tax  ptratio      lstat  medv
# count    2.0      2.0   2.000000   2.0
# mean   666.0     20.2  26.785000   5.0
# std      0.0      0.0   5.381083   0.0
# min    666.0     20.2  22.980000   5.0
# 25%    666.0     20.2  24.882500   5.0
# 50%    666.0     20.2  26.785000   5.0
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(boston_df_min_medv.corr(), annot=True, fmt=".2f", annot_kws={'size': 18})
# Out:
# <Axes: >

# %%
# I  rooms per dwelling = RM

# %%
boston_df[boston_df.rm > 7]
# Out:
#          crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 2     0.02729   0.0   7.07     0  0.4690  7.185  61.1  4.9671    2  242
# 4     0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622    3  222
# 40    0.03359  75.0   2.95     0  0.4280  7.024  15.8  5.4011    3  252
# 55    0.01311  90.0   1.22     0  0.4030  7.249  21.9  8.6966    5  226
# 64    0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229    3  216
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 364   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016  97.5  1.2024   24  666
# 375  19.60910   0.0  18.10     0  0.6710  7.313  97.9  1.3163   24  666
# 453   8.24809   0.0  18.10     0  0.7130  7.393  99.3  2.4527   24  666
# 482   5.73116   0.0  18.10     0  0.5320  7.061  77.0  3.4106   24  666
#
#      ptratio  lstat  medv
# 2       17.8   4.03  34.7
# 4       18.7   5.33  36.2
# ...

# %%
b_more_than_8_rm = boston_df[boston_df.rm > 8]

# %%
b_more_than_8_rm
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %%
b_more_than_8_rm.describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(b_more_than_8_rm.corr(), annot=True, fmt=".2f", annot_kws={'size': 18})
# Out:
# <Axes: >

# %% [markdown]
# ##### From this matrix we see that if the rooms per dwelling are increasing, the target variable (medv), doesn't really change that much. Same goes for the correlation with (ptratio). The rest of the features seem to be mostly positively correlated

# %%
b_lessEq_than_8_rm = boston_df[boston_df.rm <= 8]

# %%
b_lessEq_than_8_rm
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(b_lessEq_than_8_rm.corr(), annot=True, fmt=".2f", annot_kws={'size': 18})
# Out:
# <Axes: >

# %% [markdown]
# ##### Less than or equal to 8 for rooms per dwelling (rm), seems to have a change in the opposite (positive) direction for the target variable 'medv'

# %%
plt.figure(figsize=(5, 10))
boston_df.boxplot('rm')
plt.xlabel('Rooms per dwelling (RM)')
plt.title('Distribution of Rooms per dwelling in Boston Suburbs')
plt.show()
